# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
im1=cv.imread("C:/Users/ADMIN/Pictures/coco.jpg")

# %%
plt.imshow(im1)
plt.title('img')
plt.show()
