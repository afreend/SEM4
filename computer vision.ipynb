# %%
pip install opencv-python
# Out:
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/c7/ec/9dabb6a9abfdebb3c45b0cc52dec901caafef2b2c7e7d6a839ed86d81e91/opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.6 MB 1.2 MB/s eta 0:00:33
#    ---------------------------------------- 0.2/38.6 MB 1.5 MB/s eta 0:00:26
#    ---------------------------------------- 0.3/38.6 MB 1.7 MB/s eta 0:00:23
#     --------------------------------------- 0.6/38.6 MB 2.2 MB/s eta 0:00:18
#     --------------------------------------- 0.7/38.6 MB 2.2 MB/s eta 0:00:18
#     --------------------------------------- 0.8/38.6 MB 2.5 MB/s eta 0:00:16
#    - -------------------------------------- 1.0/38.6 MB 2.6 MB/s eta 0:00:15
#    - -------------------------------------- 1.1/38.6 MB 2.5 MB/s eta 0:00:16
# ...

# %%
import cv2

# %%
import numpy as np

# %%
cv2.imread("C:/Users/ADMIN/Pictures/Screenshots/Screenshot (2).jpg")

# %%
cv2.imshow("w1",im1)
cv2.waitkey(0)
cv2.destroyAcewindow()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 cv2.imshow("w1",im1)
#       2 cv2.waitkey(0)
#       3 cv2.destroyAcewindow()
#
# NameError: name 'im1' is not defined
